# %% [markdown]
# # Notebook Intro:
#
# In this notebook, I import cleaned training data and perform basic EDA on it.  This includes seeing the correlation between each column and the sale price (which will exclude non-numeric columns for now).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import cleaned training data
filepath = '../datasets/interim_files/train_clean.csv'

df = pd.read_csv(filepath)
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           0.0     13517   Pave  none
# 1  544  531379050           60        RL          43.0     11492   Pave  none
# 2  153  535304180           20        RL          68.0      7922   Pave  none
# 3  318  916386060           60        RL          73.0      9802   Pave  none
# 4  255  906425045           50        RL          82.0     14235   Pave  none
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0    none  none
# 1       IR1          Lvl  ...            0         0    none  none
# 2       Reg          Lvl  ...            0         0    none  none
# 3       Reg          Lvl  ...            0         0    none  none
# 4       IR1          Lvl  ...            0         0    none  none
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %%
df.corr()[['SalePrice']]
# Out:
#                  SalePrice
# Id               -0.055072
# PID              -0.252480
# MS SubClass      -0.085339
# Lot Frontage      0.179545
# Lot Area          0.295845
# Overall Qual      0.799978
# Overall Cond     -0.094233
# Year Built        0.571860
# Year Remod/Add    0.549397
# Mas Vnr Area      0.512699
# BsmtFin SF 1      0.424380
# BsmtFin SF 2      0.019387
# Bsmt Unf SF       0.191275
# Total Bsmt SF     0.631975
# 1st Flr SF        0.623523
# 2nd Flr SF        0.250946
# Low Qual Fin SF  -0.041153
# Gr Liv Area       0.699026
# Bsmt Full Bath    0.284514
# Bsmt Half Bath   -0.043856
# Full Bath         0.538471
# Half Bath         0.278486
# Bedroom AbvGr     0.138336
# Kitchen AbvGr    -0.126232
# TotRms AbvGrd     0.505188
# Fireplaces        0.471222
# Garage Yr Blt     0.258027
# Garage Cars       0.647015
# Garage Area       0.648661
# Wood Deck SF      0.328729
# Open Porch SF     0.325625
# Enclosed Porch   -0.138048
# 3Ssn Porch        0.049865
# ...

# %%
plt.figure(figsize=(7,15))

sns.heatmap(df.corr()[['SalePrice']].sort_values('SalePrice'),
           annot=True,
           vmin=-1,
           vmax=1,
           cmap='viridis');

plt.title('Sale Price vs all numeric features');

# %%
# top 5 features in plot
Features = ['Overall Qual','Gr Liv Area','Garage Area','Garage Cars','Total Bsmt SF']

#check to see if related
df[Features].corr()

sns.heatmap(df[Features].corr(),
           annot=True,
           vmin=-1,
           vmax=1,
           cmap='viridis');

plt.title('Top 5 correlated features to Sale Price')
# Out:
# Text(0.5, 1.0, 'Top 5 correlated features to Sale Price')

# %%
# we're ok

# %%
# top 5 features in plot
Features = ['Overall Qual','Gr Liv Area','Garage Area','Garage Cars','Total Bsmt SF','SalePrice']

#check to see if related
df[Features].corr()

sns.heatmap(df[Features].corr()[['SalePrice']][0:5],
           annot=True,
           vmin=-1,
           vmax=1,
           cmap='viridis');
plt.title('Sale Price vs top 5 correlated features')
# Out:
# Text(0.5, 1.0, 'Sale Price vs top 5 correlated features')

# %%
plt.figure(figsize = (10,5))
plt.title('Overall Quality Rating vs Sale Price')
plt.bar(df['Overall Qual'],df['SalePrice']);
plt.xlabel('Quality Rating')
plt.ylabel('Sale Price [$]')
# Out:
# Text(0, 0.5, 'Sale Price [$]')

# %% [markdown]
# # Notebook Summary of Work:
#
# In this notebook, I import cleaned training data and perform basic EDA on it.  This includes seeing the correlation between each column and the sale price (which will exclude non-numeric columns for now).
